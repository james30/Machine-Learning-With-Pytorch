# %% [markdown]
# <a href="https://colab.research.google.com/github/james30/Machine-Learning-With-Pytorch/blob/main/wineclassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🍷 Wine Classification

# %% [markdown]
# In this lab, you will build a neural network to classify wine types.
#
# ### How to Work
#
# - Fill in the blanks (`___`)
# - Run the code step by step
# - Fix errors if they appear
#
# ---
#
# ### Understand the Dataset
#
# Before building the model, check:
#
# - How many **input features**?
# - How many **output classes**?
#
# ---
#
# ### Design Tips
#
# - Use ReLU for activation
# - Choose reasonable hidden layer sizes
# - Try different designs if needed
#
# ---

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# %%
wine = load_wine()
X = wine.data
y = wine.target

print(X.shape)
# Out:
# (178, 13)

# %%
scaler = ___
X = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=___, random_state=42
)

X_train = torch.FloatTensor(___)
X_test = torch.FloatTensor(___)

y_train = torch.LongTensor(___)
y_test = torch.LongTensor(___)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2972/1772690947.py in <cell line: 0>()
#       1 scaler = ___
# ----> 2 X = scaler.fit_transform(X)
#       3
#       4 X_train, X_test, y_train, y_test = train_test_split(
#       5     X, y, test_size=___, random_state=42
#
# AttributeError: 'str' object has no attribute 'fit_transform'

# %%
class WineModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(___, ___)
        self.fc2 = nn.Linear(___, ___)
        self.out = nn.Linear(___, ___)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = ___(self.fc2(x))
        x = self.out(x)
        return x

# %%
model = ___

# %%
criterion = ___
optimizer = optim.Adam(model.parameters(), lr=___)

# %%
epochs = 100

for epoch in range(epochs):
    y_pred = ___
    loss = ___

    optimizer.___
    loss.___
    optimizer.___

    if epoch % 10 == 0:
        print(epoch, loss.item())

# %%
with torch.no_grad():
    preds = ___
    predicted = torch.argmax(preds, dim=1)

accuracy = accuracy_score(___, ___)
print("Accuracy:", accuracy)

# %%
assert X_train.shape[1] == 13
print("Input shape OK")

if accuracy > 0.85:
    print("Good job!")
else:
    print("Accuracy too low")
