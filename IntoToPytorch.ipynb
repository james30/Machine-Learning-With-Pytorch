# %% [markdown]
# <a href="https://colab.research.google.com/github/james30/Machine-Learning-With-Pytorch/blob/main/IntoToPytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **TENSORS**
#
# *   A torch.Tensor is a multi-dimensional matrix containing elements of a single data type.
#
# *   Similar To Numpy Arrays, but full of fun things that make them work better on GPU's (vs regular CPU's).
#
# *  default data type of float32.
#
# * More suitable for deep learning than a numpy array.

# %%
import torch
import numpy as np

# %% [markdown]
# **1. Creating Tensor from Python Data**

# %%
import torch

# t1 = torch.tensor([1,2,3])
#  print(t1)

# t2 = torch.tensor([[1,2],[3,4]])
# print(t2)

# %% [markdown]
# **2. Creating Tensor from Zeros and Ones**

# %%
# zeros = torch.zeros(2, 3)
# print(zeros)

# ones = torch.ones(2, 3)
# print(ones)

# %% [markdown]
# **3. Creating Tensor from Custom Value**

# %%
filled = torch.full((3, 3), 7)
print(filled)
# Out:
# tensor([[7, 7, 7],
#         [7, 7, 7],
#         [7, 7, 7]])

# %% [markdown]
# **4. Random Tensor Creation**

# %%
# rand_uniform = torch.rand(2, 3)
# print(rand_uniform)

# rand_normal = torch.randn(2, 3)
# print(rand_normal)

# %% [markdown]
# **5. Sequence Tensor - arrage()**

# %%
# seq = torch.arange(0, 10)
# print(seq)

# step_seq = torch.arange(0, 10, 2)
# print(step_seq)

# %% [markdown]
# **6. Evenly Spaced Values - linspace()**

# %%
# lin = torch.linspace(0, 1, steps=5)
# print(lin)

# %% [markdown]
# **7. Identity Matrix**

# %%
# eye = torch.eye(3)
# print(eye)

# %% [markdown]
# **8. Tensor Like Another Tensor**

# %%
# a = torch.rand(2, 2)

# zeros_like = torch.zeros_like(a)
# ones_like = torch.ones_like(a)

# print(zeros_like)
# print(ones_like)

# %% [markdown]
# **9. Data Type**

# %%
# int_tensor = torch.zeros((2,2), dtype=torch.int32)
# float_tensor = torch.zeros((2,2), dtype=torch.float32)

# print(int_tensor.dtype)
# print(float_tensor.dtype)

# %% [markdown]
# **10. GPU**

# %%
# create a tensor
x = torch.tensor([[1, 2], [3, 4]])

# move to GPU if available
device = 'cuda' if torch.cuda.is_available() else 'cpu'
x = x.to(device)

print('Tensor on device:', device)
print(x)
# Out:
# Tensor on device: cpu
# tensor([[1, 2],
#         [3, 4]])

# %% [markdown]
# **11. From NumPy - Pytorch**

# %%
# import numpy as np

# np_array = np.array([1,2,3])
# tensor_from_np = torch.from_numpy(np_array)

# print(tensor_from_np)

# %% [markdown]
# **12. Empty Tensor**

# %%
# empty = torch.empty(2,3)
# print(empty)
